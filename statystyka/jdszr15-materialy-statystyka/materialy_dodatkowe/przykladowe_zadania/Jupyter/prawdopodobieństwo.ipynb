# %% [markdown]
# ![iSA logo](../iSA_logo.png)
# ### Materiały do zajęć Statystyka
# #### Kurs Junior Data Scientist
#
# **Wojciech Artichowicz**

# %% [markdown]
# 2) Student umie odpowiedzieć na dwadzieścia pięć spośród trzydziestu pytań egzaminacyjnych. Znaleźć prawdopodobieństwo tego, że student odpowie w pełni poprawnie na zadane mu trzy pytania.

# %%
from fractions import Fraction

Fraction(25,30)*Fraction(24,29)*Fraction(23,28)
# Out:
# Fraction(115, 203)
