# %% [markdown]
# ![iSA logo](../iSA_logo.png)
# ### Materiały do zajęć Statystyka
# #### Kurs Junior Data Scientist
#
# **Wojciech Artichowicz**

# %% [markdown]
# 1. Dane są następujące zbiory: $A={a,b,c,d}$, $B={c,d,e}$, $C={a,d}$. Znajdź zbiory: $A \cup B$, $A \cap B$, $A - C$.

# %% [markdown]
# Definicja zmiennych ułatwiająca dalsze manipulacje

# %%
a = "a"
b = "b"
c = "c"
d = "d"
e = "e"

# %% [markdown]
# Definicja zbiorów

# %%
A = {a,b,c,d}
B = {c,d,e}
C = {a,d}

# %% [markdown]
# Suma zbiorów $A\cup B$

# %%
A | B
# Out:
# {'a', 'b', 'c', 'd', 'e'}

# %% [markdown]
# Iloczyn zbiorów $A\cap B$

# %%
A & B
# Out:
# {'c', 'd'}

# %% [markdown]
# Różnica zbiorów $A - B$

# %%
A - C
# Out:
# {'b', 'c'}

# %% [markdown]
# 2. Pewna firma rozważa dołączanie do zakupu pakietu próbek kosmetyków. Do wyboru jest $10$ różnych produktów, przy czym pakiet testowy ma się składać z próbek $3$ różnych produktów. Ile jest możliwych pakietów próbek? Wypisz wszystkie rodzaje pakietów gratisowych.

# %%
from scipy.special import binom

# %%
binom(10,3) # symbol Newtona, obliczona wartość zwraca liczbę kombinacji bez powtórzeń
# Out:
# 120.0

# %%
from itertools import combinations

produkty = set(range(1,11)) #dany produkt jest oznaczony liczbą od 1 do 10 
gratisy = set( combinations(produkty,3) )

# %%
len(gratisy)
# Out:
# 120

# %%
gratisy
# Out:
# {(1, 2, 3),
#  (1, 2, 4),
#  (1, 2, 5),
#  (1, 2, 6),
#  (1, 2, 7),
#  (1, 2, 8),
#  (1, 2, 9),
#  (1, 2, 10),
#  (1, 3, 4),
#  (1, 3, 5),
#  (1, 3, 6),
#  (1, 3, 7),
#  (1, 3, 8),
#  (1, 3, 9),
#  (1, 3, 10),
#  (1, 4, 5),
#  (1, 4, 6),
#  (1, 4, 7),
#  (1, 4, 8),
#  (1, 4, 9),
#  (1, 4, 10),
#  (1, 5, 6),
#  (1, 5, 7),
#  (1, 5, 8),
#  (1, 5, 9),
#  (1, 5, 10),
#  (1, 6, 7),
#  (1, 6, 8),
#  (1, 6, 9),
#  (1, 6, 10),
#  (1, 7, 8),
#  (1, 7, 9),
#  (1, 7, 10),
#  (1, 8, 9),
#  (1, 8, 10),
#  (1, 9, 10),
#  (2, 3, 4),
#  (2, 3, 5),
#  (2, 3, 6),
#  (2, 3, 7),
#  (2, 3, 8),
#  (2, 3, 9),
#  (2, 3, 10),
#  (2, 4, 5),
#  (2, 4, 6),
#  (2, 4, 7),
#  (2, 4, 8),
#  (2, 4, 9),
#  (2, 4, 10),
#  (2, 5, 6),
#  (2, 5, 7),
#  (2, 5, 8),
#  (2, 5, 9),
#  (2, 5, 10),
#  (2, 6, 7),
#  (2, 6, 8),
#  (2, 6, 9),
#  (2, 6, 10),
#  (2, 7, 8),
#  (2, 7, 9),
#  (2, 7, 10),
#  (2, 8, 9),
#  (2, 8, 10),
#  (2, 9, 10),
#  (3, 4, 5),
#  (3, 4, 6),
#  (3, 4, 7),
#  (3, 4, 8),
#  (3, 4, 9),
#  (3, 4, 10),
# ...
