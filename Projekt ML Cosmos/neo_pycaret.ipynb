# %%
# %pip install pycaret
# Out:
# Collecting pycaretNote: you may need to restart the kernel to use updated packages.
#
#   Obtaining dependency information for pycaret from https://files.pythonhosted.org/packages/3e/6f/b3d59fac3869a7685e68aecdd35c336800bce8c8d3b45687bb82cf9a2848/pycaret-3.3.2-py3-none-any.whl.metadata
#   Using cached pycaret-3.3.2-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: ipython>=5.5.0 in c:\users\donaj\anaconda3\lib\site-packages (from pycaret) (8.15.0)
# Requirement already satisfied: ipywidgets>=7.6.5 in c:\users\donaj\anaconda3\lib\site-packages (from pycaret) (8.0.4)
# Requirement already satisfied: tqdm>=4.62.0 in c:\users\donaj\anaconda3\lib\site-packages (from pycaret) (4.65.0)
# Requirement already satisfied: numpy<1.27,>=1.21 in c:\users\donaj\anaconda3\lib\site-packages (from pycaret) (1.24.3)
# Requirement already satisfied: pandas<2.2.0 in c:\users\donaj\anaconda3\lib\site-packages (from pycaret) (2.0.3)
# Requirement already satisfied: jinja2>=3 in c:\users\donaj\anaconda3\lib\site-packages (from pycaret) (3.1.2)
# Requirement already satisfied: scipy<=1.11.4,>=1.6.1 in c:\users\donaj\anaconda3\lib\site-packages (from pycaret) (1.11.1)
# Requirement already satisfied: joblib<1.4,>=1.2.0 in c:\users\donaj\anaconda3\lib\site-packages (from pycaret) (1.2.0)
# Requirement already satisfied: scikit-learn>1.4.0 in c:\users\donaj\anaconda3\lib\site-packages (from pycaret) (1.5.0)
# Collecting pyod>=1.1.3 (from pycaret)
#   Using cached pyod-2.0.0-py3-none-any.whl
# Requirement already satisfied: imbalanced-learn>=0.12.0 in c:\users\donaj\anaconda3\lib\site-packages (from pycaret) (0.12.3)
# Collecting category-encoders>=2.4.0 (from pycaret)
#   Obtaining dependency information for category-encoders>=2.4.0 from https://files.pythonhosted.org/packages/7f/e5/79a62e5c9c9ddbfa9ff5222240d408c1eeea4e38741a0dc8343edc7ef1ec/category_encoders-2.6.3-py2.py3-none-any.whl.metadata
#   Using cached category_encoders-2.6.3-py2.py3-none-any.whl.metadata (8.0 kB)
# Collecting lightgbm>=3.0.0 (from pycaret)
#   Obtaining dependency information for lightgbm>=3.0.0 from https://files.pythonhosted.org/packages/e1/4c/4685ccfae9806f561de716e32549190c1f533dde5bcadaf83bdf23972cf0/lightgbm-4.3.0-py3-none-win_amd64.whl.metadata
#   Using cached lightgbm-4.3.0-py3-none-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numba>=0.55.0 in c:\users\donaj\anaconda3\lib\site-packages (from pycaret) (0.57.1)
# Requirement already satisfied: requests>=2.27.1 in c:\users\donaj\anaconda3\lib\site-packages (from pycaret) (2.31.0)
# Requirement already satisfied: psutil>=5.9.0 in c:\users\donaj\anaconda3\lib\site-packages (from pycaret) (5.9.0)
# Requirement already satisfied: markupsafe>=2.0.1 in c:\users\donaj\anaconda3\lib\site-packages (from pycaret) (2.1.1)
# Requirement already satisfied: importlib-metadata>=4.12.0 in c:\users\donaj\anaconda3\lib\site-packages (from pycaret) (6.0.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\donaj\anaconda3\lib\site-packages (from pycaret) (5.9.2)
# Requirement already satisfied: cloudpickle in c:\users\donaj\anaconda3\lib\site-packages (from pycaret) (2.2.1)
# Collecting deprecation>=2.1.0 (from pycaret)
#   Obtaining dependency information for deprecation>=2.1.0 from https://files.pythonhosted.org/packages/02/c3/253a89ee03fc9b9682f1541728eb66db7db22148cd94f89ab22528cd1e1b/deprecation-2.1.0-py2.py3-none-any.whl.metadata
#   Using cached deprecation-2.1.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: xxhash in c:\users\donaj\anaconda3\lib\site-packages (from pycaret) (2.0.2)
# Requirement already satisfied: matplotlib<3.8.0 in c:\users\donaj\anaconda3\lib\site-packages (from pycaret) (3.7.2)
# Collecting scikit-plot>=0.3.7 (from pycaret)
#   Obtaining dependency information for scikit-plot>=0.3.7 from https://files.pythonhosted.org/packages/7c/47/32520e259340c140a4ad27c1b97050dd3254fdc517b1d59974d47037510e/scikit_plot-0.3.7-py3-none-any.whl.metadata
#   Using cached scikit_plot-0.3.7-py3-none-any.whl.metadata (7.1 kB)
# Collecting yellowbrick>=1.4 (from pycaret)
#   Obtaining dependency information for yellowbrick>=1.4 from https://files.pythonhosted.org/packages/06/35/c7d44bb541c06bc41b3239b27af79ea0ecc7dbb156ee1335576f99c58b91/yellowbrick-1.5-py3-none-any.whl.metadata
#   Using cached yellowbrick-1.5-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: plotly>=5.14.0 in c:\users\donaj\anaconda3\lib\site-packages (from pycaret) (5.22.0)
# Requirement already satisfied: kaleido>=0.2.1 in c:\users\donaj\anaconda3\lib\site-packages (from pycaret) (0.2.1)
# Requirement already satisfied: schemdraw==0.15 in c:\users\donaj\anaconda3\lib\site-packages (from pycaret) (0.15)
# Collecting plotly-resampler>=0.8.3.1 (from pycaret)
#   Obtaining dependency information for plotly-resampler>=0.8.3.1 from https://files.pythonhosted.org/packages/b5/4a/45150bb460637d05653940bcb8f9a14b6ba2fb4c0a454485a2fa8088b88e/plotly_resampler-0.10.0-py3-none-any.whl.metadata
#   Using cached plotly_resampler-0.10.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: statsmodels>=0.12.1 in c:\users\donaj\anaconda3\lib\site-packages (from pycaret) (0.14.0)
# Collecting sktime==0.26.0 (from pycaret)
#   Obtaining dependency information for sktime==0.26.0 from https://files.pythonhosted.org/packages/90/4c/ef5aa0d46210e974df138cc014955d2d5acb6d36af0ce1ee145d276e4a35/sktime-0.26.0-py3-none-any.whl.metadata
#   Using cached sktime-0.26.0-py3-none-any.whl.metadata (29 kB)
# Collecting tbats>=1.1.3 (from pycaret)
#   Obtaining dependency information for tbats>=1.1.3 from https://files.pythonhosted.org/packages/63/94/1949dc644c3fa05b736b988dc8058122f8c0187778ff9f18070bce2d4ddd/tbats-1.1.3-py3-none-any.whl.metadata
#   Using cached tbats-1.1.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting pmdarima>=2.0.4 (from pycaret)
#   Obtaining dependency information for pmdarima>=2.0.4 from https://files.pythonhosted.org/packages/ac/f8/6c9364602b13f0dba129b53acd1344859690911a4d5021560d9fd6aa087f/pmdarima-2.0.4-cp311-cp311-win_amd64.whl.metadata
#   Using cached pmdarima-2.0.4-cp311-cp311-win_amd64.whl.metadata (8.0 kB)
# Requirement already satisfied: packaging in c:\users\donaj\anaconda3\lib\site-packages (from sktime==0.26.0->pycaret) (23.1)
# Requirement already satisfied: scikit-base<0.8.0 in c:\users\donaj\anaconda3\lib\site-packages (from sktime==0.26.0->pycaret) (0.7.8)
# Collecting scikit-learn>1.4.0 (from pycaret)
#   Obtaining dependency information for scikit-learn>1.4.0 from https://files.pythonhosted.org/packages/79/3d/02d5d3ed359498fec3abdf65407d3c07e3b8765af17464969055aaec5171/scikit_learn-1.4.2-cp311-cp311-win_amd64.whl.metadata
#   Using cached scikit_learn-1.4.2-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\donaj\anaconda3\lib\site-packages (from category-encoders>=2.4.0->pycaret) (0.5.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\donaj\anaconda3\lib\site-packages (from imbalanced-learn>=0.12.0->pycaret) (3.5.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\donaj\anaconda3\lib\site-packages (from importlib-metadata>=4.12.0->pycaret) (3.11.0)
# Requirement already satisfied: backcall in c:\users\donaj\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.2.0)
# Requirement already satisfied: decorator in c:\users\donaj\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\donaj\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\donaj\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\donaj\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\donaj\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\donaj\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\donaj\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.2.0)
# Requirement already satisfied: traitlets>=5 in c:\users\donaj\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (5.7.1)
# Requirement already satisfied: colorama in c:\users\donaj\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.4.6)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\donaj\anaconda3\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (6.25.0)
# Requirement already satisfied: widgetsnbextension~=4.0 in c:\users\donaj\anaconda3\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in c:\users\donaj\anaconda3\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (3.0.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\donaj\anaconda3\lib\site-packages (from matplotlib<3.8.0->pycaret) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\donaj\anaconda3\lib\site-packages (from matplotlib<3.8.0->pycaret) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\donaj\anaconda3\lib\site-packages (from matplotlib<3.8.0->pycaret) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\donaj\anaconda3\lib\site-packages (from matplotlib<3.8.0->pycaret) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\donaj\anaconda3\lib\site-packages (from matplotlib<3.8.0->pycaret) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\donaj\anaconda3\lib\site-packages (from matplotlib<3.8.0->pycaret) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\donaj\anaconda3\lib\site-packages (from matplotlib<3.8.0->pycaret) (2.8.2)
# Requirement already satisfied: fastjsonschema in c:\users\donaj\anaconda3\lib\site-packages (from nbformat>=4.2.0->pycaret) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\donaj\anaconda3\lib\site-packages (from nbformat>=4.2.0->pycaret) (4.17.3)
# Requirement already satisfied: jupyter-core in c:\users\donaj\anaconda3\lib\site-packages (from nbformat>=4.2.0->pycaret) (5.3.0)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in c:\users\donaj\anaconda3\lib\site-packages (from numba>=0.55.0->pycaret) (0.40.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\donaj\anaconda3\lib\site-packages (from pandas<2.2.0->pycaret) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\donaj\anaconda3\lib\site-packages (from pandas<2.2.0->pycaret) (2023.3)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\donaj\anaconda3\lib\site-packages (from plotly>=5.14.0->pycaret) (8.2.2)
# Collecting dash>=2.9.0 (from plotly-resampler>=0.8.3.1->pycaret)
#   Obtaining dependency information for dash>=2.9.0 from https://files.pythonhosted.org/packages/63/22/bc266b167111e70a2da940e78b78d22fea5b1ee32b512ed0789bd6cc2a9f/dash-2.17.0-py3-none-any.whl.metadata
#   Using cached dash-2.17.0-py3-none-any.whl.metadata (10 kB)
# Collecting orjson<4.0.0,>=3.8.0 (from plotly-resampler>=0.8.3.1->pycaret)
#   Obtaining dependency information for orjson<4.0.0,>=3.8.0 from https://files.pythonhosted.org/packages/f9/b7/3815984df03b677644c90cd4893d6293c80ef1c9f3a8493807bc1eb47da7/orjson-3.10.3-cp311-none-win_amd64.whl.metadata
#   Using cached orjson-3.10.3-cp311-none-win_amd64.whl.metadata (50 kB)
# Requirement already satisfied: tsdownsample>=0.1.3 in c:\users\donaj\anaconda3\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.1.3)
# Collecting Cython!=0.29.18,!=0.29.31,>=0.29 (from pmdarima>=2.0.4->pycaret)
#   Obtaining dependency information for Cython!=0.29.18,!=0.29.31,>=0.29 from https://files.pythonhosted.org/packages/18/ec/f47a721071d084d6c2b6783eb8d058b964b1450cb708d920d0d792f42001/Cython-3.0.10-cp311-cp311-win_amd64.whl.metadata
#   Using cached Cython-3.0.10-cp311-cp311-win_amd64.whl.metadata (3.2 kB)
# Requirement already satisfied: urllib3 in c:\users\donaj\anaconda3\lib\site-packages (from pmdarima>=2.0.4->pycaret) (1.26.16)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\users\donaj\anaconda3\lib\site-packages (from pmdarima>=2.0.4->pycaret) (68.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\donaj\anaconda3\lib\site-packages (from requests>=2.27.1->pycaret) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\donaj\anaconda3\lib\site-packages (from requests>=2.27.1->pycaret) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\donaj\anaconda3\lib\site-packages (from requests>=2.27.1->pycaret) (2024.2.2)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in c:\users\donaj\anaconda3\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.2.2)
# Requirement already satisfied: Werkzeug<3.1 in c:\users\donaj\anaconda3\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.2.3)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\donaj\anaconda3\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\donaj\anaconda3\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\donaj\anaconda3\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (5.0.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\donaj\anaconda3\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (4.7.1)
# Requirement already satisfied: retrying in c:\users\donaj\anaconda3\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.3.4)
# Requirement already satisfied: nest-asyncio in c:\users\donaj\anaconda3\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.5.6)
# Requirement already satisfied: comm>=0.1.1 in c:\users\donaj\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\donaj\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\donaj\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (7.4.9)
# Requirement already satisfied: pyzmq>=20 in c:\users\donaj\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (23.2.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\donaj\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (6.3.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\donaj\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\donaj\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\donaj\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.18.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\donaj\anaconda3\lib\site-packages (from jupyter-core->nbformat>=4.2.0->pycaret) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\donaj\anaconda3\lib\site-packages (from jupyter-core->nbformat>=4.2.0->pycaret) (305.1)
# Requirement already satisfied: six in c:\users\donaj\anaconda3\lib\site-packages (from patsy>=0.5.1->category-encoders>=2.4.0->pycaret) (1.16.0)
# Requirement already satisfied: wcwidth in c:\users\donaj\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=5.5.0->pycaret) (0.2.5)
# Requirement already satisfied: executing in c:\users\donaj\anaconda3\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\donaj\anaconda3\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\donaj\anaconda3\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret) (0.2.2)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\donaj\anaconda3\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.1)
# Requirement already satisfied: click>=8.0 in c:\users\donaj\anaconda3\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (8.0.4)
# Requirement already satisfied: entrypoints in c:\users\donaj\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (0.4)
# Using cached pycaret-3.3.2-py3-none-any.whl (486 kB)
# Using cached sktime-0.26.0-py3-none-any.whl (21.8 MB)
# Using cached category_encoders-2.6.3-py2.py3-none-any.whl (81 kB)
# Using cached deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Using cached lightgbm-4.3.0-py3-none-win_amd64.whl (1.3 MB)
# Using cached plotly_resampler-0.10.0-py3-none-any.whl (80 kB)
# Using cached pmdarima-2.0.4-cp311-cp311-win_amd64.whl (614 kB)
# Using cached scikit_learn-1.4.2-cp311-cp311-win_amd64.whl (10.6 MB)
# Using cached scikit_plot-0.3.7-py3-none-any.whl (33 kB)
# Using cached tbats-1.1.3-py3-none-any.whl (44 kB)
# Using cached yellowbrick-1.5-py3-none-any.whl (282 kB)
# Using cached Cython-3.0.10-cp311-cp311-win_amd64.whl (2.8 MB)
# Using cached dash-2.17.0-py3-none-any.whl (7.5 MB)
# Using cached orjson-3.10.3-cp311-none-win_amd64.whl (138 kB)
# Installing collected packages: orjson, deprecation, Cython, scikit-learn, lightgbm, yellowbrick, sktime, scikit-plot, pyod, dash, pmdarima, plotly-resampler, category-encoders, tbats, pycaret
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.5.0
#     Uninstalling scikit-learn-1.5.0:
#       Successfully uninstalled scikit-learn-1.5.0
# Successfully installed Cython-3.0.10 category-encoders-2.6.3 dash-2.17.0 deprecation-2.1.0 lightgbm-4.3.0 orjson-3.10.3 plotly-resampler-0.10.0 pmdarima-2.0.4 pycaret-3.3.2 pyod-2.0.0 scikit-learn-1.4.2 scikit-plot-0.3.7 sktime-0.26.0 tbats-1.1.3 yellowbrick-1.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tables 3.8.0 requires blosc2~=2.0.0, which is not installed.

# %%
import pandas as pd
from imblearn.combine import SMOTEENN
import pycaret
from pycaret.classification import setup
from pycaret.classification import compare_models

# %%
df = pd.read_csv('neo.csv')

# %%
print(df.dtypes)
# Out:
# id                      int64
# name                   object
# est_diameter_min      float64
# est_diameter_max      float64
# relative_velocity     float64
# miss_distance         float64
# orbiting_body          object
# sentry_object            bool
# absolute_magnitude    float64
# hazardous                bool
# dtype: object

# %%
# Setup environment
s = setup(
    data=df,
    target='hazardous',
    experiment_name='Neo Prediction',
    session_id=42,
    train_size=0.75,
    categorical_features=['orbiting_body'],
    numeric_features=['est_diameter_min', 'est_diameter_max', 'relative_velocity', 'miss_distance', 'absolute_magnitude'],
    normalize=True,
    normalize_method='minmax',
    fix_imbalance=True,
    fix_imbalance_method=SMOTEENN(),
    date_features=None,
    ignore_features=['name', 'sentry_object'],
    remove_outliers=True,
    outliers_threshold=0.05,
    remove_multicollinearity=True,
    multicollinearity_threshold=0.9,
    polynomial_features=True,
    polynomial_degree=2
)
# Out:
# <style type="text/css">
# #T_99f8e_row10_col1, #T_99f8e_row16_col1, #T_99f8e_row18_col1, #T_99f8e_row20_col1, #T_99f8e_row22_col1, #T_99f8e_row24_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_99f8e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_99f8e_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_99f8e_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_99f8e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_99f8e_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_99f8e_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_99f8e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_99f8e_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_99f8e_row1_col1" class="data row1 col1" >hazardous</td>
#     </tr>
#     <tr>
#       <th id="T_99f8e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_99f8e_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_99f8e_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_99f8e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_99f8e_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_99f8e_row3_col1" class="data row3 col1" >(90836, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_99f8e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_99f8e_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_99f8e_row4_col1" class="data row4 col1" >(110309, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_99f8e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_99f8e_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_99f8e_row5_col1" class="data row5 col1" >(88069, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_99f8e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_99f8e_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_99f8e_row6_col1" class="data row6 col1" >(22709, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_99f8e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_99f8e_row7_col0" class="data row7 col0" >Ignore features</td>
#       <td id="T_99f8e_row7_col1" class="data row7 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_99f8e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_99f8e_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_99f8e_row8_col1" class="data row8 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_99f8e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_99f8e_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_99f8e_row9_col1" class="data row9 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_99f8e_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_99f8e_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_99f8e_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_99f8e_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_99f8e_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_99f8e_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_99f8e_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_99f8e_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_99f8e_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_99f8e_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_99f8e_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_99f8e_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_99f8e_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_99f8e_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_99f8e_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_99f8e_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_99f8e_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_99f8e_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_99f8e_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_99f8e_row16_col0" class="data row16 col0" >Polynomial features</td>
#       <td id="T_99f8e_row16_col1" class="data row16 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_99f8e_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_99f8e_row17_col0" class="data row17 col0" >Polynomial degree</td>
#       <td id="T_99f8e_row17_col1" class="data row17 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_99f8e_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_99f8e_row18_col0" class="data row18 col0" >Remove multicollinearity</td>
#       <td id="T_99f8e_row18_col1" class="data row18 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_99f8e_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_99f8e_row19_col0" class="data row19 col0" >Multicollinearity threshold</td>
#       <td id="T_99f8e_row19_col1" class="data row19 col1" >0.900000</td>
#     </tr>
#     <tr>
#       <th id="T_99f8e_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_99f8e_row20_col0" class="data row20 col0" >Remove outliers</td>
#       <td id="T_99f8e_row20_col1" class="data row20 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_99f8e_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_99f8e_row21_col0" class="data row21 col0" >Outliers threshold</td>
#       <td id="T_99f8e_row21_col1" class="data row21 col1" >0.050000</td>
#     </tr>
#     <tr>
#       <th id="T_99f8e_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_99f8e_row22_col0" class="data row22 col0" >Fix imbalance</td>
#       <td id="T_99f8e_row22_col1" class="data row22 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_99f8e_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_99f8e_row23_col0" class="data row23 col0" >Fix imbalance method</td>
#       <td id="T_99f8e_row23_col1" class="data row23 col1" >SMOTEENN(enn=None, n_jobs=None, random_state=None, sampling_strategy='auto',
#          smote=None)</td>
#     </tr>
#     <tr>
#       <th id="T_99f8e_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_99f8e_row24_col0" class="data row24 col0" >Normalize</td>
#       <td id="T_99f8e_row24_col1" class="data row24 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_99f8e_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_99f8e_row25_col0" class="data row25 col0" >Normalize method</td>
#       <td id="T_99f8e_row25_col1" class="data row25 col1" >minmax</td>
#     </tr>
#     <tr>
#       <th id="T_99f8e_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_99f8e_row26_col0" class="data row26 col0" >Fold Generator</td>
#       <td id="T_99f8e_row26_col1" class="data row26 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_99f8e_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_99f8e_row27_col0" class="data row27 col0" >Fold Number</td>
#       <td id="T_99f8e_row27_col1" class="data row27 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_99f8e_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_99f8e_row28_col0" class="data row28 col0" >CPU Jobs</td>
#       <td id="T_99f8e_row28_col1" class="data row28 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_99f8e_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_99f8e_row29_col0" class="data row29 col0" >Use GPU</td>
#       <td id="T_99f8e_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_99f8e_level0_ro

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_fab70 th {
#   text-align: left;
# }
# #T_fab70_row0_col0, #T_fab70_row0_col2, #T_fab70_row0_col3, #T_fab70_row0_col5, #T_fab70_row0_col7, #T_fab70_row1_col0, #T_fab70_row1_col1, #T_fab70_row1_col2, #T_fab70_row1_col3, #T_fab70_row1_col4, #T_fab70_row1_col5, #T_fab70_row1_col6, #T_fab70_row1_col7, #T_fab70_row2_col0, #T_fab70_row2_col1, #T_fab70_