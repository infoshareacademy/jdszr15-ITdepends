# %% [markdown]
# covid

# %% [markdown]
# import libraries and csv file

# %%
pip install -U scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\bartb\anaconda3\envs\infoshare_virtual_env\lib\site-packages (1.4.2)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\bartb\anaconda3\envs\infoshare_virtual_env\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\bartb\anaconda3\envs\infoshare_virtual_env\lib\site-packages (from scikit-learn) (1.13.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\bartb\anaconda3\envs\infoshare_virtual_env\lib\site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\bartb\anaconda3\envs\infoshare_virtual_env\lib\site-packages (from scikit-learn) (3.4.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#import csv file
covid = pd.read_csv("CovidData/Covid Data.csv")

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 21 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   USMER                 1048575 non-null  int64
#  1   MEDICAL_UNIT          1048575 non-null  int64
#  2   SEX                   1048575 non-null  int64
#  3   PATIENT_TYPE          1048575 non-null  int64
#  4   DATE_DIED             1048575 non-null  object
#  5   INTUBED               1048575 non-null  int64
#  6   PNEUMONIA             1048575 non-null  int64
#  7   AGE                   1048575 non-null  int64
#  8   PREGNANT              1048575 non-null  int64
#  9   DIABETES              1048575 non-null  int64
#  10  COPD                  1048575 non-null  int64
#  11  ASTHMA                1048575 non-null  int64
#  12  INMSUPR               1048575 non-null  int64
#  13  HIPERTENSION          1048575 non-null  int64
#  14  OTHER_DISEASE         1048575 non-null  int64
#  15  CARDIOVASCULAR        1048575 non-null  int64
#  16  OBESITY               1048575 non-null  int64
#  17  RENAL_CHRONIC         1048575 non-null  int64
#  18  TOBACCO               1048575 non-null  int64
#  19  CLASIFFICATION_FINAL  1048575 non-null  int64
#  20  ICU                   1048575 non-null  int64
# dtypes: int64(20), object(1)
# memory usage: 168.0+ MB

# %%
covid
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 0            2             1    1             1  03/05/2020       97
# 1            2             1    2             1  03/06/2020       97
# 2            2             1    2             2  09/06/2020        1
# 3            2             1    1             1  12/06/2020       97
# 4            2             1    2             1  21/06/2020       97
# ...        ...           ...  ...           ...         ...      ...
# 1048570      2            13    2             1  9999-99-99       97
# 1048571      1            13    2             2  9999-99-99        2
# 1048572      2            13    2             1  9999-99-99       97
# 1048573      2            13    2             1  9999-99-99       97
# 1048574      2            13    2             1  9999-99-99       97
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  \
# 0                1   65         2         2  ...       2        2
# 1                1   72        97         2  ...       2        2
# 2                2   55        97         1  ...       2        2
# 3                2   53         2         2  ...       2        2
# 4                2   68        97         1  ...       2        2
# ...            ...  ...       ...       ...  ...     ...      ...
# 1048570          2   40        97         2  ...       2        2
# 1048571          2   51        97         2  ...       2        2
# 1048572          2   55        97         2  ...       2        2
# 1048573          2   28        97         2  ...       2        2
# 1048574          2   52        97         2  ...       2        2
#
#          HIPERTENSION  OTHER_DISEASE  CARDIOVASCULAR  OBESITY  RENAL_CHRONIC  \
# 0                   1              2               2        2              2
# 1                   1              2               2        1              1
# 2                   2              2               2        2              2
# 3                   2              2               2        2              2
# 4                   1              2               2        2              2
# ...               ...            ...             ...      ...            ...
# 1048570             2              2               2        2              2
# 1048571             1              2               2        2              2
# 1048572             2              2               2        2              2
# 1048573             2              2               2        2              2
# 1048574             2              2               2        2              2
#
#          TOBACCO  CLASIFFICATION_FINAL  ICU
# 0              2                     3   97
# 1              2                     5   97
# 2              2                     3    2
# 3              2                     7   97
# 4              2                     3   97
# ...          ...                   ...  ...
# 1048570        2                     7   97
# 1048571        2                     7    2
# 1048572        2                     7   97
# 1048573        2                     7   97
# 1048574        2                     7   97
#
# [1048575 rows x 21 columns]

# %%
covid["DATE_OF_DEATH"] = covid["DATE_DIED"]

# %%
# covid["DATE_OF_DEATH"] = pd.to_datetime(covid['DATE_OF_DEATH'], format="%d/%m/%Y")

# %%
covid["DATE_OF_DEATH"]
# Out:
# 0          03/05/2020
# 1          03/06/2020
# 2          09/06/2020
# 3          12/06/2020
# 4          21/06/2020
#               ...
# 1048570    9999-99-99
# 1048571    9999-99-99
# 1048572    9999-99-99
# 1048573    9999-99-99
# 1048574    9999-99-99
# Name: DATE_OF_DEATH, Length: 1048575, dtype: object

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 22 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   USMER                 1048575 non-null  int64
#  1   MEDICAL_UNIT          1048575 non-null  int64
#  2   SEX                   1048575 non-null  int64
#  3   PATIENT_TYPE          1048575 non-null  int64
#  4   DATE_DIED             1048575 non-null  object
#  5   INTUBED               1048575 non-null  int64
#  6   PNEUMONIA             1048575 non-null  int64
#  7   AGE                   1048575 non-null  int64
#  8   PREGNANT              1048575 non-null  int64
#  9   DIABETES              1048575 non-null  int64
#  10  COPD                  1048575 non-null  int64
#  11  ASTHMA                1048575 non-null  int64
#  12  INMSUPR               1048575 non-null  int64
#  13  HIPERTENSION          1048575 non-null  int64
#  14  OTHER_DISEASE         1048575 non-null  int64
#  15  CARDIOVASCULAR        1048575 non-null  int64
#  16  OBESITY               1048575 non-null  int64
#  17  RENAL_CHRONIC         1048575 non-null  int64
#  18  TOBACCO               1048575 non-null  int64
#  19  CLASIFFICATION_FINAL  1048575 non-null  int64
#  20  ICU                   1048575 non-null  int64
#  21  DATE_OF_DEATH         1048575 non-null  object
# dtypes: int64(20), object(2)
# memory usage: 176.0+ MB

# %%
covid_dup = covid[covid.duplicated(keep=False)]

# %%
covid_dup.sample(10)
# Out:
#         USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 891892      2            12    1             1  9999-99-99       97
# 673098      2            12    1             1  9999-99-99       97
# 151043      2             4    2             1  9999-99-99       97
# 65930       2             4    1             1  9999-99-99       97
# 314362      1             4    1             1  9999-99-99       97
# 350203      1             6    2             2  9999-99-99        2
# 595429      1            12    1             1  9999-99-99       97
# 684651      2            12    1             1  9999-99-99       97
# 426448      2             9    2             1  9999-99-99       97
# 323150      1             4    1             1  9999-99-99       97
#
#         PNEUMONIA  AGE  PREGNANT  DIABETES  ...  INMSUPR  HIPERTENSION  \
# 891892          2   20         2         2  ...        2             2
# 673098          2   55         2         2  ...        2             2
# 151043          2   22        97         2  ...        2             2
# 65930           2   43         2         2  ...        2             2
# 314362          2   26         2         2  ...        2             2
# 350203          1   55        97         2  ...        2             2
# 595429          2   80         2         2  ...        2             1
# 684651          2   21         2         2  ...        2             2
# 426448          2   28        97         2  ...        2             2
# 323150          2   27         2         2  ...        2             2
#
#         OTHER_DISEASE  CARDIOVASCULAR  OBESITY  RENAL_CHRONIC  TOBACCO  \
# 891892              2               2        2              2        2
# 673098              2               2        2              2        2
# 151043              2               2        2              2        1
# 65930               2               2        2              2        2
# 314362              2               2        2              2        2
# 350203              2               2        2              2        2
# 595429              2               2        2              2        2
# 684651              2               2        2              2        2
# 426448              2               2        2              2        2
# 323150              2               2        2              2        2
#
#         CLASIFFICATION_FINAL  ICU  DATE_OF_DEATH
# 891892                     7   97     9999-99-99
# 673098                     5   97     9999-99-99
# 151043                     3   97     9999-99-99
# 65930                      3   97     9999-99-99
# 314362                     7   97     9999-99-99
# 350203                     3    2     9999-99-99
# 595429                     3   97     9999-99-99
# 684651                     6   97     9999-99-99
# 426448                     7   97     9999-99-99
# 323150                     7   97     9999-99-99
#
# [10 rows x 22 columns]

# %%
cols = list(covid_dup.columns)

# %%
# covid_dup["REAL_DUPLICATE"] = covid_dup.duplicated(subset=cols)

# %%
covid_dup_real = covid_dup.duplicated(subset=cols)

# %%
covid_dup_real.value_counts()
# Out:
# True     812049
# False     55672
# Name: count, dtype: int64

# %%
covid_dup.sample(10)
# Out:
#         USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 988219      2            12    2             1  9999-99-99       97
# 719734      1            12    1             1  9999-99-99       97
# 63523       2             4    2             1  9999-99-99       97
# 285754      2             4    2             1  9999-99-99       97
# 535599      2            12    2             1  9999-99-99       97
# 874327      2            12    1             1  9999-99-99       97
# 197341      1             4    1             1  9999-99-99       97
# 249494      2             4    1             1  9999-99-99       97
# 871168      2            12    2             1  9999-99-99       97
# 706692      1            12    1             1  9999-99-99       97
#
#         PNEUMONIA  AGE  PREGNANT  DIABETES  ...  INMSUPR  HIPERTENSION  \
# 988219          2   44        97         2  ...        2             2
# 719734          2   51         2         2  ...        2             1
# 63523           2   47        97         2  ...        1             2
# 285754          2   31        97         2  ...        2             2
# 535599          2   51        97         2  ...        2             1
# 874327          2   45         2         2  ...        2             1
# 197341          2   67         2         2  ...        2             1
# 249494          2   37         2         2  ...        2             2
# 871168          2   43        97         2  ...        2             2
# 706692          2   32         2         2  ...        2             2
#
#         OTHER_DISEASE  CARDIOVASCULAR  OBESITY  RENAL_CHRONIC  TOBACCO  \
# 988219              2               2        2              2        2
# 719734              2               2        2              2        2
# 63523               1               2        1              2        2
# 285754              2               2        2              2        2
# 535599              2               2        1              2        2
# 874327              2               2        2              2        2
# 197341              2               2        2              2        2
# 249494              2               2        2              2        2
# 871168              2               2        2              2        1
# 706692              2               2        2              2        2
#
#         CLASIFFICATION_FINAL  ICU  DATE_OF_DEATH
# 988219                     7   97     9999-99-99
# 719734                     6   97     9999-99-99
# 63523                      3   97     9999-99-99
# 285754                     7   97     9999-99-99
# 535599                     3   97     9999-99-99
# 874327                     7   97     9999-99-99
# 197341                     6   97     9999-99-99
# 249494                     7   97     9999-99-99
# 871168                     7   97     9999-99-99
# 706692                     6   97     9999-99-99
#
# [10 rows x 22 columns]

# %% [markdown]
# prepare data

# %%
# delete duplicate rows
covid_no_dup = covid.drop_duplicates(subset=cols, keep='first', inplace=False)

# %%
covid_no_dup
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 0            2             1    1             1  03/05/2020       97
# 1            2             1    2             1  03/06/2020       97
# 2            2             1    2             2  09/06/2020        1
# 3            2             1    1             1  12/06/2020       97
# 4            2             1    2             1  21/06/2020       97
# ...        ...           ...  ...           ...         ...      ...
# 1048568      1            13    2             1  9999-99-99       97
# 1048569      1            13    1             2  9999-99-99        2
# 1048571      1            13    2             2  9999-99-99        2
# 1048572      2            13    2             1  9999-99-99       97
# 1048574      2            13    2             1  9999-99-99       97
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  ...  INMSUPR  HIPERTENSION  \
# 0                1   65         2         2  ...        2             1
# 1                1   72        97         2  ...        2             1
# 2                2   55        97         1  ...        2             2
# 3                2   53         2         2  ...        2             2
# 4                2   68        97         1  ...        2             1
# ...            ...  ...       ...       ...  ...      ...           ...
# 1048568          2   47        97         1  ...        2             2
# 1048569          2   56         2         1  ...        2             2
# 1048571          2   51        97         2  ...        2             1
# 1048572          2   55        97         2  ...        2             2
# 1048574          2   52        97         2  ...        2             2
#
#          OTHER_DISEASE  CARDIOVASCULAR  OBESITY  RENAL_CHRONIC  TOBACCO  \
# 0                    2               2        2              2        2
# 1                    2               2        1              1        2
# 2                    2               2        2              2        2
# 3                    2               2        2              2        2
# 4                    2               2        2              2        2
# ...                ...             ...      ...            ...      ...
# 1048568              2               2        2              2        2
# 1048569              2               2        2              2        2
# 1048571              2               2        2              2        2
# 1048572              2               2        2              2        2
# 1048574              2               2        2              2        2
#
#          CLASIFFICATION_FINAL  ICU  DATE_OF_DEATH
# 0                           3   97     03/05/2020
# 1                           5   97     03/06/2020
# 2                           3    2     09/06/2020
# 3                           7   97     12/06/2020
# 4                           3   97     21/06/2020
# ...                       ...  ...            ...
# 1048568                     7   97     9999-99-99
# 1048569                     7    2     9999-99-99
# 1048571                     7    2     9999-99-99
# 1048572                     7   97     9999-99-99
# 1048574                     7   97     9999-99-99
#
# [236526 rows x 22 columns]

# %%
# delete not used columns
covid.drop(columns=['MEDICAL_UNIT','USMER'], inplace =True)

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 20 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   SEX                   1048575 non-null  int64
#  1   PATIENT_TYPE          1048575 non-null  int64
#  2   DATE_DIED             1048575 non-null  object
#  3   INTUBED               1048575 non-null  int64
#  4   PNEUMONIA             1048575 non-null  int64
#  5   AGE                   1048575 non-null  int64
#  6   PREGNANT              1048575 non-null  int64
#  7   DIABETES              1048575 non-null  int64
#  8   COPD                  1048575 non-null  int64
#  9   ASTHMA                1048575 non-null  int64
#  10  INMSUPR               1048575 non-null  int64
#  11  HIPERTENSION          1048575 non-null  int64
#  12  OTHER_DISEASE         1048575 non-null  int64
#  13  CARDIOVASCULAR        1048575 non-null  int64
#  14  OBESITY               1048575 non-null  int64
#  15  RENAL_CHRONIC         1048575 non-null  int64
#  16  TOBACCO               1048575 non-null  int64
#  17  CLASIFFICATION_FINAL  1048575 non-null  int64
#  18  ICU                   1048575 non-null  int64
#  19  DATE_OF_DEATH         1048575 non-null  object
# dtypes: int64(18), object(2)
# memory usage: 160.0+ MB

# %%
# rename columns
covid.rename(columns=
             {'PATIENT_TYPE':'HOSPITALIZED',
              'DATE_DIED':'DEAD',
              'INMSUPR': 'IMMUNOSUPPRESSED',
              'CLASIFFICATION_FINAL': 'COVID_TEST_RESULT',
              'TOBACCO': "SMOKER",
              'CARDIOVASCULAR': 'CARDIOVASCULAR_DISEASE',
              'RENAL_CHRONIC': 'CHRONIC_KIDNEY_DISEASE',
              'ICU': 'ADMITTED_TO_ICU'}, inplace=True)

# %%
# update columns order
covid = covid.loc[:,
                  ['COVID_TEST_RESULT', 
                   'HOSPITALIZED',
                   'INTUBED',
                   'ADMITTED_TO_ICU',
                   'DEAD',
                   'AGE',
                   'SEX',
                   'PREGNANT',
                   'SMOKER',
                   'PNEUMONIA',
                   'COPD',
                   'ASTHMA',
                   'IMMUNOSUPPRESSED',
                   'CARDIOVASCULAR_DISEASE',
                   'HIPERTENSION',
                   'CHRONIC_KIDNEY_DISEASE',
                   'DIABETES',
                   'OBESITY',
                   'OTHER_DISEASE']]

# %%
# column "DEAD" dead: 1, alive: 0
covid['DEAD'] = covid['DEAD'].replace({'9999-99-99': 0})
covid['DEAD'] = covid['DEAD'].apply(lambda x: 1 if x != 0 else 0)

# %%
# column "SEX" female: 1, male: 0
covid['SEX'] = covid['SEX'].replace({2:0})

# %%
# change 2 for 0 ('False'), 97, 98 and 99 for 0
covid[['INTUBED','ADMITTED_TO_ICU','PREGNANT','SMOKER','PNEUMONIA','COPD','ASTHMA','IMMUNOSUPPRESSED',
       'CARDIOVASCULAR_DISEASE','HIPERTENSION','CHRONIC_KIDNEY_DISEASE', 'DIABETES','OBESITY','OTHER_DISEASE']] = covid[[
           'INTUBED','ADMITTED_TO_ICU','PREGNANT','SMOKER','PNEUMONIA','COPD','ASTHMA','IMMUNOSUPPRESSED',
           'CARDIOVASCULAR_DISEASE','HIPERTENSION', 'CHRONIC_KIDNEY_DISEASE','DIABETES','OBESITY','OTHER_DISEASE']].replace({2: 0, 97: 0, 98: 0, 99: 0})

# %%
#change column "HOSPITALIZED" to 0,1 format
covid['HOSPITALIZED'] = covid['HOSPITALIZED'].replace({1: 0, 2: 1})

# %%
#update column "COVID_TEST_RESULT" to 0,1 format
covid['COVID_TEST_RESULT'] = covid['COVID_TEST_RESULT'].apply(lambda x: 1 if x in [1,2,3] else 0)

# %%
covid["COVID_TEST_RESULT"].value_counts()
# Out:
# COVID_TEST_RESULT
# 0    656596
# 1    391979
# Name: count, dtype: int64

# %%
covid['COVID_NEGATIV'] = covid['COVID_TEST_RESULT'] == 0

# %%
covid['COVID_NEGATIV'].replace({False: 0, True: 1}, inplace=True)
# Out:
# C:\Users\bartb\AppData\Local\Temp\ipykernel_32268\617110477.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   covid['COVID_NEGATIV'].replace({False: 0, True: 1}, inplace=True)
# C:\Users\bartb\AppData\Local\Temp\ipykernel_32268\617110477.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   covid['COVID_NEGATIV'].replace({False: 0, True: 1}, inplace=True)

# %%
covid['COVID_NEGATIV']
# Out:
# 0          0
# 1          1
# 2          0
# 3          1
# 4          0
#           ..
# 1048570    1
# 1048571    1
# 1048572    1
# 1048573    1
# 1048574    1
# Name: COVID_NEGATIV, Length: 1048575, dtype: int64

# %%
covid[["COVID_TEST_RESULT", "COVID_NEGATIV"]]
# Out:
#          COVID_TEST_RESULT  COVID_NEGATIV
# 0                        1              0
# 1                        0              1
# 2                        1              0
# 3                        0              1
# 4                        1              0
# ...                    ...            ...
# 1048570                  0              1
# 1048571                  0              1
# 1048572                  0              1
# 1048573                  0              1
# 1048574                  0              1
#
# [1048575 rows x 2 columns]

# %%
#function creating a values for age group
def grouping_age(row) -> str:
    if row['AGE'] < 18:
        val = '-18'
    elif row['AGE'] < 30:
        val = '18-30'
    elif row['AGE'] < 45:
        val = '30-45'
    elif row['AGE'] < 60:
        val = '45-60'
    else:
        val = '60+'
    return val

# %%
#create column "AGE_GROUP"
covid["AGE_GROUP"] = covid.apply(grouping_age, axis=1)

# %%
#move column "AGE_GROUP" next to "AGE" column
column_to_move = covid.pop('AGE_GROUP')
covid.insert(6, "AGE_GROUP", column_to_move)

# %%
#create a table grouped by age and aggregated as sum
covid_age = covid.groupby("AGE_GROUP").sum()

# %%
#create a table grouped by age and aggregated as sum
covid_age_test = covid.groupby(["AGE_GROUP", "COVID_TEST_RESULT"]).size()

# %%
covid_age_test
# Out:
# AGE_GROUP  COVID_TEST_RESULT
# -18        0                     44238
#            1                     10166
# 18-30      0                    140395
#            1                     59378
# 30-45      0                    232417
#            1                    130091
# 45-60      0                    159852
#            1                    115105
# 60+        0                     79694
#            1                     77239
# dtype: int64

# %%
covid_age
# Out:
#            COVID_TEST_RESULT  HOSPITALIZED  INTUBED  ADMITTED_TO_ICU   DEAD  \
# AGE_GROUP
# -18                    10166         11870     1178             1493    802
# 18-30                  59378         11766      992              826   1378
# 30-45                 130091         35634     4088             2645   7699
# 45-60                 115105         61387    10845             5200  23387
# 60+                    77239         79374    16553             6694  43676
#
#                 AGE     SEX  PREGNANT  SMOKER  PNEUMONIA   COPD  ASTHMA  \
# AGE_GROUP
# -18          469251   26104       300     366       4715     79    2141
# 18-30       4975986  104360      4553   18425       7881    346    6859
# 30-45      13330681  185477      3207   32428      26752   1249   11504
# 45-60      14093239  137302        55   20203      44896   3318    7626
# 60+        10955094   71821        16   12954      55794  10070    3442
#
#            IMMUNOSUPPRESSED  CARDIOVASCULAR_DISEASE  HIPERTENSION  \
# AGE_GROUP
# -18                    1492                     730           312
# 18-30                  1444                    1117          4310
# 30-45                  3224                    3070         26491
# 45-60                  3951                    5431         61855
# 60+                    4059                   10421         69761
#
#            CHRONIC_KIDNEY_DISEASE  DIABETES  OBESITY  OTHER_DISEASE  \
# AGE_GROUP
# -18                           322       324     1585           2385
# 18-30                        1555      2632    19902           3270
# 30-45                        3415     18944    58550           7767
# 45-60                        5641     50422    53457           7604
# 60+                          7971     52667    26322           7014
#
#            COVID_NEGATIV
# AGE_GROUP
# -18                44238
# 18-30             140395
# 30-45             232417
# 45-60             159852
# 60+                79694

# %%
test = covid[(covid["COVID_TEST_RESULT"]) == 1]

# %%
test_gr = test.groupby(["AGE_GROUP", "DEAD"]).size()

# %%
test_gr
# Out:
# AGE_GROUP  DEAD
# -18        0         9971
#            1          195
# 18-30      0        58666
#            1          712
# 30-45      0       124828
#            1         5263
# 45-60      0        98110
#            1        16995
# 60+        0        46168
#            1        31071
# dtype: int64

# %%
18819+18539
# Out:
# 37358

# %% [markdown]
# charts

# %%
#sum of positive covid test in each age group
ax = sns.barplot(x="AGE_GROUP", y="COVID_TEST_RESULT", estimator="sum", data=covid_age, palette="YlGnBu")
for container in ax.containers:
    ax.bar_label(container)
ax.set(xlabel="grupa wiekowa", ylabel="ilość z pozytywnym testem")
# Out:
# C:\Users\bartb\AppData\Local\Temp\ipykernel_32268\2512485428.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x="AGE_GROUP", y="COVID_TEST_RESULT", estimator="sum", data=covid_age, palette="YlGnBu")
# [Text(0.5, 0, 'grupa wiekowa'), Text(0, 0.5, 'ilość z pozytywnym testem')]

# %%
# calculate the distribution of `Clicked` per `Rank`
distribution = pd.crosstab(covid["AGE_GROUP"], covid["COVID_TEST_RESULT"], normalize='index')

# %%
covid["COVID_TEST_RESULT"]
# Out:
# 0          1
# 1          0
# 2          1
# 3          0
# 4          1
#           ..
# 1048570    0
# 1048571    0
# 1048572    0
# 1048573    0
# 1048574    0
# Name: COVID_TEST_RESULT, Length: 1048575, dtype: int64

# %%
distribution = pd.crosstab(covid["AGE_GROUP"], covid["COVID_TEST_RESULT"], normalize='index')

# %%
ax = sns.histplot(
    data=covid,
    x="AGE_GROUP", hue="COVID_TEST_RESULT",
    multiple="fill", stat="percent",
    discrete=True, shrink=.8, legend=True, palette='colorblind')
plt.legend(labels = covid['COVID_TEST_RESULT'].unique()[::1], bbox_to_anchor = (1, 1), fontsize = 8)
plt.gca().invert_xaxis()
ax.margins(y=1)
sns.move_legend(
    ax, "lower center",
    bbox_to_anchor=(.5, 1), ncol=2, title="DEAD", frameon=False,
)

# %%
counts = covid.groupby("AGE_GROUP")["COVID_TEST_RESULT"].count()
counts
# Out:
# AGE_GROUP
# -18       54404
# 18-30    199773
# 30-45    362508
# 45-60    274957
# 60+      156933
# Name: COVID_TEST_RESULT, dtype: int64

# %%
axe = sns.histplot(covid,  x="AGE_GROUP", hue="COVID_TEST_RESULT", multiple = 'stack', palette = 'colorblind', shrink = 0.8, legend=True)
# for i in range(len(counts)):
#     axe.text(i, counts[i]/2, str(counts[i]),
#              fontdict= dict(color = 'red', fontsize = 12),
#              horizontalalignment = 'center'
#              )

plt.legend(labels = covid['COVID_TEST_RESULT'].unique()[::1], bbox_to_anchor = (1, 1), fontsize = 8)
plt.gca().invert_xaxis()
# plt.yticks(np.arange(0,100,20), np.arange(100,0,-20))
axe.margins(y=0)
sns.move_legend(
    axe, "lower center",
    bbox_to_anchor=(.5, 1), ncol=2, title="DEAD", frameon=False,
)
# (
#     axe.Plot(glue, x="SST-2", y="MRPC", text="Model")
#     .add(so.Text())
# )

# %%
# plot the cumsum, with reverse hue order
sns.barplot(data=distribution.cumsum(axis=1).stack().reset_index(name='Dist'),
            x=covid["AGE_GROUP"], covid["COVID_TEST_RESULT"], hue=covid["COVID_TEST_RESULT"],
            hue_order = distribution.columns[::-1],   # reverse hue order so that the taller bars got plotted first
            dodge=False)

# calculate the distribution of `Clicked` per `Rank`
# distribution = pd.crosstab(df.Rank, df.Clicked, normalize='index')

# # plot the cumsum, with reverse hue order
# sns.barplot(data=distribution.cumsum(axis=1).stack().reset_index(name='Dist'),
#             x='Rank', y='Dist', hue='Clicked',
#             hue_order = distribution.columns[::-1],   # reverse hue order so that the taller bars got plotted first
#             dodge=False)
# Out:
#   Cell In[63], line 5
#     dodge=False)
#                ^
# SyntaxError: positional argument follows keyword argument

# %%
distribution
# Out:
# COVID_TEST_RESULT         0         1
# AGE_GROUP
# -18                0.813139  0.186861
# 18-30              0.702773  0.297227
# 30-45              0.641136  0.358864
# 45-60              0.581371  0.418629
# 60+                0.507822  0.492178

# %%
#defeated by date of death in each age group
ax = sns.barplot(x="AGE_GROUP", y="DEAD", estimator="sum", data=covid_age, palette="YlGnBu")
for container in ax.containers:
    ax.bar_label(container)
ax.set(xlabel="grupa wiekowa", ylabel="ilość zgonów")
# Out:
# C:\Users\bartb\AppData\Local\Temp\ipykernel_19164\1806804264.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x="AGE_GROUP", y="DEAD", estimator="sum", data=covid_age, palette="YlGnBu")
# [Text(0.5, 0, 'grupa wiekowa'), Text(0, 0.5, 'ilość zgonów')]

# %%
#median and quartiles
ax = sns.boxplot(x="COVID_TEST_RESULT", y="AGE", data=covid, hue="SEX", palette="YlGnBu")
ax.set(xlabel="wynik testu", ylabel="wiek")
sns.move_legend(ax, "lower center", bbox_to_anchor=(0.5, -0.4), ncol=2, title="płeć (0 - mężczyźni, 1 - kobiety)", frameon=True)

# %%
#create a table with column's values 0,1
covid_sick = covid[['COVID_TEST_RESULT','HOSPITALIZED','INTUBED','ADMITTED_TO_ICU','DEAD','AGE','SEX','PREGNANT','SMOKER','PNEUMONIA','COPD','ASTHMA','IMMUNOSUPPRESSED','CARDIOVASCULAR_DISEASE','HIPERTENSION','CHRONIC_KIDNEY_DISEASE', 'DIABETES','OBESITY','OTHER_DISEASE']]

# %%
#only positive covid patients
covid_sick = covid_sick.loc[(covid_sick['COVID_TEST_RESULT'] == 1)]

# %%
#create a list of conditions to be correlated with death
conditions = ['INTUBED','ADMITTED_TO_ICU', 'AGE','SEX','PREGNANT','SMOKER','PNEUMONIA','COPD','ASTHMA','IMMUNOSUPPRESSED','CARDIOVASCULAR_DISEASE','HIPERTENSION','CHRONIC_KIDNEY_DISEASE', 'DIABETES','OBESITY','OTHER_DISEASE']

# %% [markdown]
# korelacja pearsona - zły przykład, bo to dla wartości ciagłych a mamy 0,1

# %%
#correlating in for loop and creating a dictionary
death_corrs = {}
for condition in conditions:
    corr = round(covid_sick[condition].corr(covid_sick["DEAD"]),3)
    death_corrs[condition] = corr

# %%
#list with sorted correlations
death_corrs = sorted(death_corrs.items(), key=lambda x: x[1], reverse=True)

# %%
death_corrs
# Out:
# [('INTUBED', 0.514),
#  ('PNEUMONIA', 0.513),
#  ('AGE', 0.398),
#  ('DIABETES', 0.237),
#  ('HIPERTENSION', 0.234),
#  ('ADMITTED_TO_ICU', 0.208),
#  ('CHRONIC_KIDNEY_DISEASE', 0.129),
#  ('COPD', 0.1),
#  ('CARDIOVASCULAR_DISEASE', 0.085),
#  ('OBESITY', 0.06),
#  ('OTHER_DISEASE', 0.06),
#  ('IMMUNOSUPPRESSED', 0.05),
#  ('SMOKER', 0.011),
#  ('ASTHMA', -0.016),
#  ('PREGNANT', -0.028),
#  ('SEX', -0.093)]

# %% [markdown]
# CREATE A LOGISTIC REGRESION MODEL - to będzie dobry przykład, który omawialiśmy z Mateuszem na zajeciach

# %%
#split dataset in features (X) and target variable (Y)
#create a list of conditions to be correlated with death
features = ['INTUBED','ADMITTED_TO_ICU', 'AGE','SEX','PREGNANT','SMOKER','PNEUMONIA','COPD','ASTHMA','IMMUNOSUPPRESSED','CARDIOVASCULAR_DISEASE','HIPERTENSION','CHRONIC_KIDNEY_DISEASE', 'DIABETES','OBESITY','OTHER_DISEASE']
X = covid_sick[features] # Features
y = covid_sick["DEAD"] # Target variable

# %%
# import the logistic regresion class
from sklearn.linear_model import LogisticRegression

# create the model
model_logreg = LogisticRegression()

# fit the model with data
model_logreg.fit(X, y)

#create prediction
y_pred = model_logreg.predict(X)

# %%
#plot pneumonia vs dead logistic regresion, but without differenciate the size of dots
plt.scatter(covid_sick["PNEUMONIA"], covid_sick["DEAD"])
plt.show
pass

# %%
# import the metrics class
from sklearn import metrics

confusion_matrix = metrics.confusion_matrix(y, y_pred)
confusion_matrix
# Out:
# array([[327437,  10306],
#        [ 24894,  29342]], dtype=int64)

# %%
class_names=[0,1] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(confusion_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("bottom")
plt.tight_layout()
plt.title('Confusion matrix')
plt.ylabel('DEAD')
plt.xlabel('PREDICTED_DEAD')
# Out:
# Text(0.5, 23.52222222222222, 'PREDICTED_DEAD')

# %%
from sklearn.metrics import classification_report

target_names = ['no covid', 'covid']
print(classification_report(y, y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#     no covid       0.93      0.97      0.95    337743
#        covid       0.74      0.54      0.63     54236
#
#     accuracy                           0.91    391979
#    macro avg       0.83      0.76      0.79    391979
# weighted avg       0.90      0.91      0.90    391979

# %% [markdown]
# powyżej - skuteczność (precyzja) modelu to ok 75% - pytanie czy to wystarczająca wartość, czy da się podciągnąć wydajność modelu

# %%
#   CREATE A COEFICIENCY ARRAY FOR FEATURES AND DEAD IN LOGISTIC REGRESION
coeficiencies = logreg.coef_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[197], line 2
#       1 #   CREATE A COEFICIENCY ARRAY FOR FEATURES AND DEAD IN LOGISTIC REGRESION
# ----> 2 coeficiencies = logreg.coef_
#
# NameError: name 'logreg' is not defined

# %%
#create keys and values for a dictionary
values = []
for i in coeficiencies[0]:
    exp_coef = np.exp(i)
    values.append(exp_coef)

keys = features

print(keys)
print(values)
# Out:
# ['INTUBED', 'ADMITTED_TO_ICU', 'AGE', 'SEX', 'PREGNANT', 'SMOKER', 'PNEUMONIA', 'COPD', 'ASTHMA', 'IMMUNOSUPPRESSED', 'CARDIOVASCULAR_DISEASE', 'HIPERTENSION', 'CHRONIC_KIDNEY_DISEASE', 'DIABETES', 'OBESITY', 'OTHER_DISEASE']
# [9.132682815050599, 0.4514421061312601, 1.041207804724888, 0.6138041455276965, 0.3614800498325118, 0.47940583976330575, 3.961402433312058, 0.6839909873701778, 0.40634376338345163, 0.6617843956287944, 0.5726567052092048, 0.960861007139191, 1.153007462025574, 1.0903798402629925, 0.8487780682804891, 0.7626058964890655]

# %%
#create a dictionary with results
death_logreg = dict(zip(keys, values))
print(death_logreg)
# Out:
# {'INTUBED': 9.132682815050599, 'ADMITTED_TO_ICU': 0.4514421061312601, 'AGE': 1.041207804724888, 'SEX': 0.6138041455276965, 'PREGNANT': 0.3614800498325118, 'SMOKER': 0.47940583976330575, 'PNEUMONIA': 3.961402433312058, 'COPD': 0.6839909873701778, 'ASTHMA': 0.40634376338345163, 'IMMUNOSUPPRESSED': 0.6617843956287944, 'CARDIOVASCULAR_DISEASE': 0.5726567052092048, 'HIPERTENSION': 0.960861007139191, 'CHRONIC_KIDNEY_DISEASE': 1.153007462025574, 'DIABETES': 1.0903798402629925, 'OBESITY': 0.8487780682804891, 'OTHER_DISEASE': 0.7626058964890655}

# %% [markdown]
# na razie to słownik, pozostaje interpretacja z uwzględnieniem, czy korelacja była ujemna czy dodatnia

# %%
np.exp(2.2118595)
# Out:
# 9.132682837335953

# %% [markdown]
# WNIOSEK - jesli pajent byl intubowany to ryzyko zgonu wzrasta x9

# %%
np.exp(0.04038139)
# Out:
# 1.0412078047204814

# %% [markdown]
# WNIOSEK - z każdym rokiem życia pacjenta ryzyko zgonu wzrasta o 4% (YoY)

# %%
class Patient
