# %%
import scipy.stats as st
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# wygenerowanie zmiennej losowej

# %%
X = st.rv_discrete(values=([1,2,5], [0.1, 0.5, 0.4]))

# %%
plt.stem(X.xk, X.pmf(X.xk))
# Out:
# <StemContainer object of 3 artists>

# %%
x = np.linspace(0,6,1000)
plt.plot(x, X.cdf(x))
